# %%
 from fastai.vision import *

# %%
folder = 'pigeons'
#file = 'pigeon.csv'

# %%
path = Path('data/bird')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
#download_images(path/file, dest, max_pics=900)

# %%
folder = 'sparrow'
#file = 'sparrow.csv'

# %%
path = Path('data/bird')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
#download_images(path/file, dest, max_pics=900)

# %%
folder = 'owl'
#file = 'owl.csv'

# %%
path = Path('data/bird')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
#download_images(path/file, dest, max_pics=900)

# %%
folder = 'parrot'
#file = 'parrot.csv'

# %%
path = Path('data/bird')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
#download_images(path/file, dest, max_pics=900)

# %%
folder = 'crow'
#file = 'crows.csv'

# %%
path = Path('data/bird')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
#download_images(path/file, dest, max_pics=900)

# %%
path.ls()
# Out:
# [PosixPath('data/bird/crow'),
#  PosixPath('data/bird/parrot'),
#  PosixPath('data/bird/owl'),
#  PosixPath('data/bird/sparrow'),
#  PosixPath('data/bird/pigeons')]

# %%
classes = ['crows','pigeon','sparrow','owl','parrot']

# %%
#download_images(path/file, dest, max_pics=500)

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "

# %%
data.classes
# Out:
# ['crow', 'owl', 'parrot', 'pigeons', 'sparrow']

# %%
data.show_batch(rows=5, figsize=(7,8))
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['crow', 'owl', 'parrot', 'pigeons', 'sparrow'], 5, 399, 99)

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/hub/checkpoints/resnet34-333f7ec4.pth
# ...

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.060772</td>
#       <td>0.333977</td>
#       <td>0.131313</td>
#       <td>02:26</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.131966</td>
#       <td>0.163346</td>
#       <td>0.050505</td>
#       <td>02:23</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.738396</td>
#       <td>0.111404</td>
#       <td>0.040404</td>
#       <td>02:22</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.540018</td>
#       <td>0.100433</td>
#       <td>0.040404</td>
#       <td>02:22</td>
#     </tr>
#   </tbody>
# </table>
# ...

# %%
learn.save('stage-1')

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='13' class='' max='17' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       76.47% [13/17 27:32<08:28]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
# ...

# %%
learn.fit_one_cycle(2, max_lr=slice(3e-5,3e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.103957</td>
#       <td>0.094893</td>
#       <td>0.030303</td>
#       <td>02:28</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.082035</td>
#       <td>0.091987</td>
#       <td>0.030303</td>
#       <td>02:23</td>
#     </tr>
#   </tbody>
# </table>
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
# ...

# %%
learn.save('stage-2')

# %%
learn.load('stage-2');

# %%
interp = ClassificationInterpretation.from_learner(learn)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
# ...

# %%
from fastai.widgets import *

# %%
db = (ImageList.from_folder(path)
                   .split_none()
                   .label_from_folder()
                   .transform(get_transforms(), size=224)
                   .databunch()
     )
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "

# %%
learn_cln = cnn_learner(db, models.resnet34, metrics=error_rate)

learn_cln.load('stage-2');

# %%
ds, idxs = DatasetFormatter().from_similars(learn_cln)
# Out:
# Getting activations...
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8' class='' max='8' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8/8 01:14<00:00]
#     </div>
# ...

# %%
ImageCleaner(ds, idxs, path, duplicates=True)
# Out:
# ...
# Button(button_style='primary', description='Next Batch', layout=Layout(width='auto'), style=ButtonStyle())

# %%
learn.export()

# %%
defaults.device = torch.device('cpu')

# %%
img = open_image(path/'owl'/'21.jpg')
img
# Out:
# Image (3, 168, 299)

# %%
learn = load_learner(path)

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class
# Out:
# Category tensor(1)

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(5, max_lr=1e-5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.116773</td>
#       <td>2.404805</td>
#       <td>0.787879</td>
#       <td>02:26</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.053414</td>
#       <td>2.046609</td>
#       <td>0.777778</td>
#       <td>02:22</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.039225</td>
#       <td>1.965936</td>
#       <td>0.838384</td>
#       <td>02:22</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.015023</td>
#       <td>1.943228</td>
#       <td>0.797980</td>
#       <td>02:23</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.993778</td>
#       <td>1.960203</td>
#       <td>0.797980</td>
#       <td>02:24</td>
#     </tr>
#   </tbody>
# </table>
# ...

# %%
learn.recorder.plot_losses()

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate, pretrained=False)

# %%
learn.fit_one_cycle(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.748459</td>
#       <td>1.903467</td>
#       <td>0.767677</td>
#       <td>03:22</td>
#     </tr>
#   </tbody>
# </table>
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# ...

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.9, bs=32, 
        ds_tfms=get_transforms(do_flip=False, max_rotate=0, max_zoom=1, max_lighting=0, max_warp=0
                              ),size=224, num_workers=4).normalize(imagenet_stats)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3000: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and uses scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
# ...

# %%
learn = cnn_learner(data, models.resnet50, metrics=error_rate, ps=0, wd=0)
learn.unfreeze()
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# ...

# %%
learn.fit_one_cycle(40, slice(1e-6,1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.943956</td>
#       <td>3.742038</td>
#       <td>0.741071</td>
#       <td>01:54</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.827308</td>
#       <td>3.369883</td>
#       <td>0.743304</td>
#       <td>01:53</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.791382</td>
#       <td>3.035050</td>
#       <td>0.741071</td>
#       <td>01:58</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.723183</td>
#       <td>2.799847</td>
#       <td>0.736607</td>
#       <td>01:56</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.638329</td>
#       <td>2.554662</td>
#       <td>0.736607</td>
#       <td>01:53</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...
